# %%
import pandas as pd
import numpy as np


from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.set_theme(style="white")


from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from datetime import datetime as dt
from collections import Counter
from sklearn.base import clone 

import pickle

from tqdm import tqdm

# %% [markdown]
# # Loading the Data

# %%
df_credit = pd.read_csv('credit_train.csv', encoding="ISO-8859-1", delimiter=';' )

# %% [markdown]
# # EDA

# %%
df_credit.shape
# Out:
# (170746, 15)

# %% [markdown]
# This dataset have:
# - 170,746 rows
# - 15 columns

# %%
#Which features are available in the dataset
df_credit.columns
# Out:
# Index(['client_id', 'gender', 'age', 'marital_status', 'job_position',
#        'credit_sum', 'credit_month', 'tariff_id', 'score_shk', 'education',
#        'living_region', 'monthly_income', 'credit_count',
#        'overdue_credit_count', 'open_account_flg'],
#       dtype='object')

# %%
#Checking the first 5 rows of the dataset?
df_credit.head()
# Out:
#    client_id gender  age marital_status job_position credit_sum  credit_month  \
# 0          1      M   48            MAR          UMN   59998,00            10
# 1          2      F   28            MAR          UMN   10889,00             6
# 2          3      M   32            MAR          SPC   10728,00            12
# 3          4      F   27            DIV          SPC   12009,09            12
# 4          5      M   45            MAR          SPC   16908,89            10
#
#    tariff_id score_shk education        living_region  monthly_income  \
# 0        1.6  0,770249       GRD   ÊÐÀÑÍÎÄÀÐÑÊÈÉ ÊÐÀÉ         30000.0
# 1        1.1  0,248514       GRD               ÌÎÑÊÂÀ         43000.0
# 2        1.1  0,459589       SCH      ÎÁË ÑÀÐÀÒÎÂÑÊÀß         23000.0
# 3        1.1  0,362536       GRD    ÎÁË ÂÎËÃÎÃÐÀÄÑÊÀß         17000.0
# 4        1.1  0,421385       SCH  ×ÅËßÁÈÍÑÊÀß ÎÁËÀÑÒÜ         25000.0
#
#    credit_count  overdue_credit_count  open_account_flg
# 0           1.0                   1.0                 0
# 1           2.0                   0.0                 0
# 2           5.0                   0.0                 0
# 3           2.0                   0.0                 0
# 4           1.0                   0.0                 0

# %%
#Checking the last 5 rows of the dataset
df_credit.tail()
# Out:
#         client_id gender  age marital_status job_position credit_sum  \
# 170741     170742      F   27            UNM          SPC   64867,00
# 170742     170743      F   24            MAR          SPC   17640,00
# 170743     170744      F   31            UNM          SPC   27556,47
# 170744     170745      F   53            DIV          PNA    6189,00
# 170745     170746      M   49            MAR          SPC   12787,00
#
#         credit_month  tariff_id score_shk education         living_region  \
# 170741            12       1.10  0,535257       GRD  ÐÅÑÏÓÁËÈÊÀ ÒÀÒÀÐÑÒÀÍ
# 170742             6       1.60  0,573287       SCH     ÑÀÍÊÒ-ÏÅÒÅÐÁÓÐÃ Ã
# 170743            10       1.32  0,416098       GRD       ÏÐÈÌÎÐÑÊÈÉ ÊÐÀÉ
# 170744            12       1.10  0,482595       SCH        ÏÅÍÇÅÍÑÊÀß ÎÁË
# 170745            10       1.10  0,316087       GRD        ÎÁË ÌÎÑÊÎÂÑÊÀß
#
#         monthly_income  credit_count  overdue_credit_count  open_account_flg
# 170741         40000.0           6.0                   0.0                 0
# 170742         30000.0           1.0                   0.0                 0
# 170743         40000.0           1.0                   0.0                 0
# 170744         31000.0           2.0                   0.0                 0
# 170745         40000.0           3.0                   0.0                 0

# %% [markdown]
# ### By taking a pick at the first and last five rows of the dataset, I can see the following:
#
# - The columns ***gender, marital_status, job position, tarrif_id, education, open_account_flg*** contain the categorical data.
#
#
# - The columns ***credit_sum*** and ***score_shk** contain the numerical data; however, instead of a comma(,), there should be the point(.), which ***needs to be taken care*** before using descriptive statistics.
#
#
# - The remaning columns ***client_id, age, credit_month, monthly_income, credit_count, overdue_credit_count*** contain numerical data.

# %%
#Changing commas to points and converting "credit_sum" and "score_shk" data to the float dtype.
df_credit['credit_sum'] = df_credit['credit_sum'].replace(',','.', regex= True).astype(dtype = float)
df_credit['score_shk'] = df_credit['score_shk'].replace(',','.', regex= True).astype(dtype = float)

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170746 entries, 0 to 170745
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             170746 non-null  int64
#  1   gender                170746 non-null  object
#  2   age                   170746 non-null  int64
#  3   marital_status        170746 non-null  object
#  4   job_position          170746 non-null  object
#  5   credit_sum            170746 non-null  float64
#  6   credit_month          170746 non-null  int64
#  7   tariff_id             170746 non-null  float64
#  8   score_shk             170746 non-null  float64
#  9   education             170746 non-null  object
#  10  living_region         170554 non-null  object
#  11  monthly_income        170745 non-null  float64
#  12  credit_count          161516 non-null  float64
#  13  overdue_credit_count  161516 non-null  float64
#  14  open_account_flg      170746 non-null  int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 19.5+ MB

# %% [markdown]
# ### By looking at the above information, we can see that there are:
#
#   - Four features' dtype is int
#
#
#   - Five features' dtype is object
#
#
#   - Six features'  dtype is float

# %% [markdown]
# ## Checking Missing Values

# %%
round(df_credit.isnull().sum() / df_credit.shape[0], ndigits=6) * 100
# Out:
# client_id               0.0000
# gender                  0.0000
# age                     0.0000
# marital_status          0.0000
# job_position            0.0000
# credit_sum              0.0000
# credit_month            0.0000
# tariff_id               0.0000
# score_shk               0.0000
# education               0.0000
# living_region           0.1124
# monthly_income          0.0006
# credit_count            5.4057
# overdue_credit_count    5.4057
# open_account_flg        0.0000
# dtype: float64

# %% [markdown]
# - For some reason, around **5%** of values in the columns **'credit_count'** and **"overdue_credit_count"** are **NaN**.
#
# - Also, the columns **"living_region"** and **'monthly_income'** have **less than 1% of the nan values**.

# %% [markdown]
# ## The distribution of the numeric features

# %%
#Temporarily dropping the column tariff_id as it is a categorical feature.
df_credit.drop('tariff_id', axis = 1).describe()
# Out:
#            client_id            age     credit_sum   credit_month  \
# count  170746.000000  170746.000000  170746.000000  170746.000000
# mean    85373.500000      36.497283   26095.047799      10.980749
# std     49290.268869      10.546008   16234.794320       3.536698
# min         1.000000      18.000000    2736.000000       3.000000
# 25%     42687.250000      28.000000   14908.000000      10.000000
# 50%     85373.500000      34.000000   21229.000000      10.000000
# 75%    128059.750000      43.000000   32068.000000      12.000000
# max    170746.000000      71.000000  200000.000000      36.000000
#
#            score_shk  monthly_income   credit_count  overdue_credit_count  \
# count  170746.000000   170745.000000  161516.000000         161516.000000
# mean        0.469473    40138.288354       2.107308              0.046070
# std         0.124268    25044.205336       1.777128              0.211548
# min         0.000000     5000.000000       0.000000              0.000000
# 25%         0.379495    25000.000000       1.000000              0.000000
# 50%         0.461599    35000.000000       2.000000              0.000000
# 75%         0.552419    50000.000000       3.000000              0.000000
# max         1.128291   950000.000000      21.000000              3.000000
#
#        open_account_flg
# count     170746.000000
# mean           0.176028
# std            0.380845
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [markdown]
# #### The descriptive statistics of the numeric columns tell the following:
#
# - ***'age'*** column: The **average** age of clients is **36 years**, the **youngest** is **18 years**, and the **oldest** is **71** years. Also, the **standard deviation of 10** indicates the age **data are more spread-out**, which means this column contains a **high variation of ages**.
#
#
# - **'credit_month'** column: It shows that the **maximum and minimum **credit terms** are **10 months and 36 months, respectively**. **Most credit terms are around 10 to 12 months**.
#
#
# - **'monthly_income'** column: The **median** income of clients is **35,000**. In addition, the **standard deviation of the 25,044** means that some of the clients' salary either very high or very less which means it is **far from average(40138.28)**.
#
#
# - **'credit_count'** column: At the moment of application, there are **some individuals** who have up to **21 loans** and others who do not have any; however, **on average**, clients have around **2 to 3 loans**.
#
#
# - **'overdue_credit_count'** column: **Most** of the clients **do not have any overdue credits**; nevertheless, they are **some individuals who were behind schedule on a loan payment more than once**.
#
#
# - **'open_account_flg'** column: According to these samples, we can see that the bank approval for **opening a credit bank account is around 17%**. Also, it is the **target(y) column**, which is **clearly unbalanced**; therefore, before creating the model, I **need to use over/under/combined sampling** and check the model's performance.

# %% [markdown]
# ## The distribution of categorical features

# %%
df_credit.describe(include=['O'])
# Out:
#         gender marital_status job_position education   living_region
# count   170746         170746       170746    170746          170554
# unique       2              5           18         5             301
# top          F            MAR          SPC       SCH  ÎÁË ÌÎÑÊÎÂÑÊÀß
# freq     88697          93956       134680     87539           12228

# %% [markdown]
# #### The descriptive statistics of the categorical columns tell the following:
#
# - **'gender'** column: **51%(freq 88697/170746)** of clients within the sample dataset are **F(female)**, while **49% are M(men)**.(**2 unique values**)
#
#
# - **'marital_status** column : Around **55%(93956/170746)** of the clients are **married**.(**5 unique values**)
#
#
# - **'job_position'** column: According to the dataset, **78%(134680/170746)** of the clients have **SPC job positions**.(**18 unique values**)
#
#
# - **'education'** column: **Around 51%(87539/170746)** of clients have earned only the **SCH (school-high school diploma)**. (**5 unique values**)
#
#
# - **'living_region'**: This column contains the living region values of clients.(**301 unique values**)

# %% [markdown]
# ## Visualisation of categorical features

# %%
def barplot_vis(col_name:str, df):
    """
    :param col_name: The catigorical column name that need to be visualize
    return: Returns bar plot visualisation of categorical data
    """
    
    #Adjusting the graph's figure size
    plt.figure(figsize=(8,4))
    
    #Creating the DataFrame that contains the categorical labels and the count of each category.
    count_df = df[col_name].value_counts().rename_axis(col_name).reset_index(name='count')
    
    #Creating the bar plot
    ax = sns.barplot(data=count_df ,y=col_name,x='count')
    
    #Adding and making adjustments to the bar labels.
    ax.bar_label(ax.containers[0],padding= 8 ,fontsize=15, color = 'black')
    
    #Setting the color style
    sns.set_palette(sns.color_palette("pastel"))
    
    #Setting the graph's x and y labels and title.
    plt.title(f'Column: {col_name}',fontdict = {'size': 13} )
    ax.set_xlabel('Count',size = 13)
    ax.set_ylabel(col_name,size = 13)
    ax.set_yticklabels(count_df[col_name], fontdict = {'fontsize': 15})
    
    #Removing the top and right spines from the plot
    sns.despine()
    plt.show()

# %%
opened_acc_df = df_credit[df_credit['open_account_flg'] == 1]

# %% [markdown]
# #### ***Column gender***

# %%
barplot_vis('gender', df_credit)

# %% [markdown]
# - We can see that the gender contains only **two unique values, F(Female) and M(Male)**.
#
#
# - According to the bar plot, it can be seen that there are more **F(female) than M(male)** samples, **51% and 48%, respectively**.
#
#
# *Did F(female)s opened more accounts or M(male)s?*

# %%
opened_acc_df[['gender','open_account_flg','client_id']].groupby(['gender','open_account_flg']).count().sort_values('client_id', ascending = False)
# Out:
#                          client_id
# gender open_account_flg
# M      1                     15881
# F      1                     14175

# %% [markdown]
# - **Even though there are more F(female)s** samples in the dataset, the **man samples that got to open accounts are more**. **(Male = 15881, Female = 14175)**

# %% [markdown]
# #### ***Column Marital Status***

# %%
barplot_vis('marital_status', df_credit)

# %% [markdown]
# - The marital_status column has **5 unique category values**.
#
#
# - By looking at the above graph, we can see that **55%(93956/170746) ** of clients are **married**.
#
#
# - Also, the percentage of **unmarried and divorced** clients is **around (52149/170746)30% and (16970/170746)10%, respectively**.
#
#
# - The percentage of **widowed people** is less than **3%**.

# %%
opened_acc_df[['marital_status','open_account_flg','client_id']].groupby(['marital_status','open_account_flg']).count().sort_values('client_id', ascending = False)
# Out:
#                                  client_id
# marital_status open_account_flg
# MAR            1                     14368
# UNM            1                     11016
# DIV            1                      3090
# CIV            1                       846
# WID            1                       736

# %% [markdown]
# - According to the above sample data, **most of the clients who have opened credit accounts are married(47%) and unmarried(36)**%.
# <br> *Calculation = (Total opened credit accounts: 30056,  married:14368/ total 30056 =47%,  unmarried:11016/ total:30056=36%).*

# %% [markdown]
# #### ***Column Job Position***

# %%
barplot_vis('job_position', df_credit)

# %% [markdown]
# - The job_position column has **18 unique category values**.
#
#
# - **Most clients** within the sample dataset have **SPC(around 80%) type job positions**.

# %%
opened_acc_df[['job_position','open_account_flg','client_id']].groupby(['job_position','open_account_flg']).count().sort_values('client_id', ascending = False)
# Out:
#                                client_id
# job_position open_account_flg
# SPC          1                     22403
# UMN          1                      3340
# PNA          1                      1489
# BIS          1                       885
# ATP          1                       807
# DIR          1                       555
# NOR          1                       194
# WRK          1                       121
# WOI          1                        84
# INP          1                        67
# BIU          1                        46
# WRP          1                        23
# PNI          1                        20
# PNV          1                         9
# PNS          1                         6
# INV          1                         4
# HSK          1                         2
# ONB          1                         1

# %% [markdown]
#  - Clients with **SPC job positions** are those who are **opened most credit card accounts**.

# %% [markdown]
# ## Job positions

# %%
barplot_vis('education', df_credit)

# %% [markdown]
# - The education column has **5 unique categorical values**.
#
#
# - There are **more clients with SCH and GRD education levels** within the sample dataset.

# %%
opened_acc_df[['education','open_account_flg','client_id']].groupby(['education','open_account_flg']).count().sort_values('client_id', ascending = False)
# Out:
#                             client_id
# education open_account_flg
# SCH       1                     17956
# GRD       1                     10130
# UGR       1                      1837
# PGR       1                       108
# ACD       1                        25

# %%
df_credit.columns
# Out:
# Index(['client_id', 'gender', 'age', 'marital_status', 'job_position',
#        'credit_sum', 'credit_month', 'tariff_id', 'score_shk', 'education',
#        'living_region', 'monthly_income', 'credit_count',
#        'overdue_credit_count', 'open_account_flg'],
#       dtype='object')

# %%
tmp = df_credit.drop(['client_id','gender','marital_status','job_position','tariff_id','education','living_region'], axis =1 )

# %%
plt.figure(figsize = (30, 20))
s = sns.heatmap(tmp.corr(),
               annot = True, 
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 30)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 30)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# There are some moderate correalations between following features:
#    - **credit_sum and creadit_month = positive 0.23**
#    - **credit_sum and monthly income = positive 0.35**
# <br> However, the **moderate correlation is not a good reason for dropping those columns**.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Dropping Columns

# %%
df_credit.columns
# Out:
# Index(['client_id', 'gender', 'age', 'marital_status', 'job_position',
#        'credit_sum', 'credit_month', 'tariff_id', 'score_shk', 'education',
#        'living_region', 'monthly_income', 'credit_count',
#        'overdue_credit_count', 'open_account_flg'],
#       dtype='object')

# %%
df_credit.drop(['client_id','living_region'], axis = 1,inplace = True )

# %%
df_credit.columns
# Out:
# Index(['gender', 'age', 'marital_status', 'job_position', 'credit_sum',
#        'credit_month', 'tariff_id', 'score_shk', 'education', 'monthly_income',
#        'credit_count', 'overdue_credit_count', 'open_account_flg'],
#       dtype='object')

# %%
df_credit.shape
# Out:
# (170746, 13)

# %% [markdown]
# ## Filling missing value with median

# %%
df_credit.isnull().sum()
# Out:
# gender                     0
# age                        0
# marital_status             0
# job_position               0
# credit_sum                 0
# credit_month               0
# tariff_id                  0
# score_shk                  0
# education                  0
# monthly_income             1
# credit_count            9230
# overdue_credit_count    9230
# open_account_flg           0
# dtype: int64

# %% [markdown]
# Need to check the median of columns 'monthly_income', 'credit_count,' 'overdue_credit_count' before filling the Nan Values.
#
#  - 1. Need to check the median when df has samples that belong to the category open_account_flg = 1.
#
#  - 2. Need to check the median when df has samples that belong to the category open_account_flg = 0.
#
# **If the 'monthly_income,' 'credit_count,' and 'overdue_credit_count' columns' median in both categories is the same, then I am going to use the same median to fill the column's nan values of both categories**.

# %%
df_credit[['monthly_income','credit_count','overdue_credit_count']].describe()
# Out:
#        monthly_income   credit_count  overdue_credit_count
# count   170745.000000  161516.000000         161516.000000
# mean     40138.288354       2.107308              0.046070
# std      25044.205336       1.777128              0.211548
# min       5000.000000       0.000000              0.000000
# 25%      25000.000000       1.000000              0.000000
# 50%      35000.000000       2.000000              0.000000
# 75%      50000.000000       3.000000              0.000000
# max     950000.000000      21.000000              3.000000

# %%
df_credit[df_credit['open_account_flg']== 0][['monthly_income','credit_count','overdue_credit_count']].describe()
# Out:
#        monthly_income   credit_count  overdue_credit_count
# count   140689.000000  134909.000000         134909.000000
# mean     40412.558601       2.078883              0.043867
# std      25402.589188       1.750912              0.206457
# min       5000.000000       0.000000              0.000000
# 25%      25000.000000       1.000000              0.000000
# 50%      35000.000000       2.000000              0.000000
# 75%      50000.000000       3.000000              0.000000
# max     950000.000000      19.000000              3.000000

# %%
median_stats = {
    'monthly_income':int(df_credit['monthly_income'].median()),
    'credit_count':df_credit['credit_count'].median(),
    'overdue_credit_count':df_credit['overdue_credit_count'].median()
}

# %%
median_stats
# Out:
# {'monthly_income': 35000, 'credit_count': 2.0, 'overdue_credit_count': 0.0}

# %%
#Filling Nan Values with median value
df_credit['monthly_income'].fillna(median_stats['monthly_income'], inplace=True)
df_credit['credit_count'].fillna(median_stats['credit_count'], inplace=True)
df_credit['overdue_credit_count'].fillna(median_stats['overdue_credit_count'], inplace=True)

# %% [markdown]
# ### One-Hot-Encoding

# %%
on_enc = OneHotEncoder()
categorical_data = df_credit[['gender', 'marital_status', 'job_position','tariff_id','education']]
encoded_data = on_enc.fit_transform(categorical_data)
df_encoded_data = pd.DataFrame(encoded_data.toarray(), columns= on_enc.get_feature_names_out()).astype(dtype = int)

#Concatenating the encoded DataFrame with the original DataFrame.
df_encoded_data = pd.concat([df_encoded_data, df_credit], axis = 1 )

#Dropping the original categorical features
df_encoded_data.drop(['gender', 'marital_status', 'job_position','tariff_id','education'], axis = 1, inplace = True)
df_encoded_data.shape
# Out:
# (170746, 70)

# %% [markdown]
# # Feature Importance

# %%
under_sampling = RandomUnderSampler(random_state=365)

# %%
#Dividing features into X and y.
X = df_encoded_data.drop('open_account_flg', axis = 1)
y = df_encoded_data['open_account_flg']

# %%
#Under sampling 
X_under_sampled, y_under_sampled = under_sampling.fit_resample(X, y)
print(f"Combined Random Sampling: {Counter(y_under_sampled)}")
# Out:
# Combined Random Sampling: Counter({0: 30056, 1: 30056})

# %%
model_fea_imp = RandomForestClassifier(n_estimators = 1000,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)

# %%
def imp_df(column_names, importances):
    df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
    return df

#Plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title):
    imp_df.columns = ['feature', 'feature_importance']
    plt.figure(figsize = (20,15))
    sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df, orient = 'h', color = 'royalblue') \
       .set_title(title, fontsize = 20)

# %%
def drop_col_feat_imp(model, X_train, y_train, random_state = 42):
    
    #Cloning the model to have the exact same specification as the one initially trained
    model_clone = clone(model)
    # set random_state for comparability
    model_clone.random_state = random_state
    # training and scoring the benchmark model
    model_clone.fit(X_train, y_train)
    benchmark_score = model_clone.oob_score_
    # list for storing feature importances
    importances = []
    
    
    # iterating over all columns and storing feature importance (difference between benchmark and new model)
    for col in tqdm(X_train.columns):
        model_clone = clone(model)
        model_clone.random_state = random_state
        model_clone.fit(X_train.drop(col, axis = 1), y_train)
        drop_col_score = model_clone.oob_score_
        importances.append(benchmark_score - drop_col_score)
    
    importances_df = imp_df(X_train.columns, importances)
    return importances_df

# %%
X_under_sampled.columns
# Out:
# Index(['gender_F', 'gender_M', 'marital_status_CIV', 'marital_status_DIV',
#        'marital_status_MAR', 'marital_status_UNM', 'marital_status_WID',
#        'job_position_ATP', 'job_position_BIS', 'job_position_BIU',
#        'job_position_DIR', 'job_position_HSK', 'job_position_INP',
#        'job_position_INV', 'job_position_NOR', 'job_position_ONB',
#        'job_position_PNA', 'job_position_PNI', 'job_position_PNS',
#        'job_position_PNV', 'job_position_SPC', 'job_position_UMN',
#        'job_position_WOI', 'job_position_WRK', 'job_position_WRP',
#        'tariff_id_1.0', 'tariff_id_1.1', 'tariff_id_1.16', 'tariff_id_1.17',
#        'tariff_id_1.18', 'tariff_id_1.19', 'tariff_id_1.2', 'tariff_id_1.21',
#        'tariff_id_1.22', 'tariff_id_1.23', 'tariff_id_1.24', 'tariff_id_1.25',
#        'tariff_id_1.26', 'tariff_id_1.27', 'tariff_id_1.28', 'tariff_id_1.29',
#        'tariff_id_1.3', 'tariff_id_1.32', 'tariff_id_1.4', 'tariff_id_1.41',
#        'tariff_id_1.43', 'tariff_id_1.44', 'tariff_id_1.48', 'tariff_id_1.5',
#        'tariff_id_1.52', 'tariff_id_1.56', 'tariff_id_1.6', 'tariff_id_1.7',
#        'tariff_id_1.9', 'tariff_id_1.91', 'tariff_id_1.94', 'tariff_id_1.96',
#        'education_ACD', 'education_GRD', 'education_PGR', 'education_SCH',
#        'education_UGR', 'age', 'credit_sum', 'credit_month', 'score_shk',
#        'monthly_income', 'credit_count', 'overdue_credit_count'],
#       dtype='object')

# %%
feature_importance = drop_col_feat_imp(model=model_fea_imp, X_train=X_under_sampled, y_train=y_under_sampled)
# Out:
# 100%|██████████| 69/69 [53:16<00:00, 46.33s/it]

# %%
var_imp_plot(feature_importance,'Feature Importance')

# %% [markdown]
# - According to the above graph, we can see that there are categorical values from the 'job_position,' 'tariff_id,' 'education,' and 'marital_status' columns that are important and not important at the same time.
# - I think it is worse to check how the model will perform  without  these columns: 'job_position, tariff_id, education, marital_status.'

# %%
df_preprocessed = df_encoded_data.copy()

# %%
df_preprocessed.drop(['marital_status_CIV', 'marital_status_DIV',
       'marital_status_MAR', 'marital_status_UNM', 'marital_status_WID',
       'job_position_ATP', 'job_position_BIS', 'job_position_BIU',
       'job_position_DIR', 'job_position_HSK', 'job_position_INP',
       'job_position_INV', 'job_position_NOR', 'job_position_ONB',
       'job_position_PNA', 'job_position_PNI', 'job_position_PNS',
       'job_position_PNV', 'job_position_SPC', 'job_position_UMN',
       'job_position_WOI', 'job_position_WRK', 'job_position_WRP',
       'tariff_id_1.0', 'tariff_id_1.1', 'tariff_id_1.16', 'tariff_id_1.17',
       'tariff_id_1.18', 'tariff_id_1.19', 'tariff_id_1.2', 'tariff_id_1.21',
       'tariff_id_1.22', 'tariff_id_1.23', 'tariff_id_1.24', 'tariff_id_1.25',
       'tariff_id_1.26', 'tariff_id_1.27', 'tariff_id_1.28', 'tariff_id_1.29',
       'tariff_id_1.3', 'tariff_id_1.32', 'tariff_id_1.4', 'tariff_id_1.41',
       'tariff_id_1.43', 'tariff_id_1.44', 'tariff_id_1.48', 'tariff_id_1.5',
       'tariff_id_1.52', 'tariff_id_1.56', 'tariff_id_1.6', 'tariff_id_1.7',
       'tariff_id_1.9', 'tariff_id_1.91', 'tariff_id_1.94', 'tariff_id_1.96',
       'education_ACD', 'education_GRD', 'education_PGR', 'education_SCH',
       'education_UGR'], axis= 1 , inplace = True)

# %%
under_sampling = RandomUnderSampler(random_state=365)

# %%
#Dividing features into X and y.
X = df_preprocessed.drop('open_account_flg', axis = 1)
y = df_preprocessed['open_account_flg']

# %%
#Under sampling 
X_under_sampled, y_under_sampled = under_sampling.fit_resample(X, y)
print(f"Combined Random Sampling: {Counter(y_under_sampled)}")
# Out:
# Combined Random Sampling: Counter({0: 30056, 1: 30056})

# %% [markdown]
# # Training the Model

# %%
RF_model = RandomForestClassifier(oob_score = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_under_sampled, 
                                                    y_under_sampled, 
                                                    random_state=365, 
                                                    stratify=y_under_sampled, 
                                                    test_size = 0.2)

# %%
n_estimators = [100, 300, 500, 800, 1200, 2000]
max_depth = [3, 5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10, 50] 

start_time = dt.now()
hyperF = dict(n_estimators = n_estimators, max_depth = max_depth,  
              min_samples_split = min_samples_split, 
             min_samples_leaf = min_samples_leaf)

gridF = GridSearchCV(RF_model, hyperF, cv = 3, verbose = 2, 
                      n_jobs = -1)
bestF = gridF.fit(X_train, y_train)
end_time = dt.now()
# Out:
# Fitting 3 folds for each of 900 candidates, totalling 2700 fits
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  11.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=  48.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time= 1.0min
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   3.7s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  12.6s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  22.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=  50.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=  12.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=500; total time=  19.4s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  45.3s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  18.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  30.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  11.6s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  21.6s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  46.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=  18.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=800; total time=  33.3s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=  11.8s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  19.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time=  46.8s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  19.8s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  31.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   3.9s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   4.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  11.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  19.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=  45.6s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=500; total time=  19.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=800; total time=  31.6s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=  11.5s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  19.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=  47.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  21.3s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  35.5s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=2000; total time= 1.6min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   4.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   4.2s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=  11.5s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=  22.1s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time=  52.0s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=500; total time=  22.0s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=800; total time=  34.4s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=2000; total time= 1.6min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=100; total time=   4.7s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=300; total time=  12.8s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=500; total time=  21.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=1200; total time=  52.9s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=300; total time=  13.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=800; total time=  36.8s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=1200; total time=  59.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  47.3s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  18.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  23.2s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time= 3.5min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=2000; total time= 3.0min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   6.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  18.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  31.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  30.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  45.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time= 1.9min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   5.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  17.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=  32.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  35.0s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  47.3s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.1s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  18.8s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  31.0s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  31.0s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  48.6s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   6.7s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   5.9s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  19.0s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  30.7s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  33.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  46.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   6.7s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   5.5s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=  15.9s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  27.5s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=  29.1s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=  40.7s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=2000; total time= 1.9min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=   5.0s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  16.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=500; total time=  27.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=500; total time=  27.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=800; total time=  43.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=100; total time=   5.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=100; total time=   5.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=300; total time=  15.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=500; total time=  26.0s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  25.6s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time= 2.5min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  21.6s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  35.5s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  56.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=100; total time=   7.3s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=100; total time=   7.0s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=  20.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=500; total time=  34.6s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  34.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  55.2s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.9s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.6s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  21.4s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  35.0s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=  34.6s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=800; total time=  55.5s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.9s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   7.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=  20.7s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  34.8s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  39.9s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  58.4s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time= 2.5min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   9.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   8.3s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  24.8s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  11.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=  47.8s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time= 1.1min
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  12.8s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  13.8s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=  32.6s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=  50.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=  30.1s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.7s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.7s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  10.9s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  19.1s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=  45.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  21.8s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  30.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   4.1s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   3.9s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  11.8s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=  19.9s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time=  47.5s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  19.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  30.9s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   3.9s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   3.9s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  11.7s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  18.5s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  46.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  18.6s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  30.4s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  12.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  19.3s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time=  47.1s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=  11.1s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  30.1s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=  50.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  35.5s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=2000; total time= 1.6min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=2000; total time= 1.4min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=300; total time=  12.9s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=500; total time=  22.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=1200; total time=  52.9s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=500; total time=  25.3s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=800; total time=  37.0s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=100; total time=   4.6s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=100; total time=   4.6s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=300; total time=  12.7s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=500; total time=  21.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=1200; total time=  53.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=500; total time=  22.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=800; total time=  37.7s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=2000; total time= 1.6min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time= 2.9min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  22.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  51.3s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  21.3s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time= 1.6min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  16.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  31.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=  16.7s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=800; total time=  41.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=  49.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.5s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  18.4s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  30.9s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  18.5s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  47.9s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=800; total time=  48.8s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=2000; total time= 2.2min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   5.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=  18.5s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  27.9s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  28.6s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=800; total time=  40.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=300; total time=  16.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=500; total time=  27.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  17.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=800; total time=  43.7s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=800; total time=  43.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=15, n_estimators=2000; total time= 1.7min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.0s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  26.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  42.0s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  37.8s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  35.7s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  34.4s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=  55.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  20.4s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  34.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  35.4s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  56.1s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   7.5s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  21.5s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=  34.7s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  34.5s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  55.8s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 2.5min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   7.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   7.1s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  21.1s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  37.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  44.8s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=2000; total time= 2.9min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  25.2s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  45.2s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  41.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  59.6s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 2.7min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   8.1s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   8.9s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=  22.4s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  38.7s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=1200; total time= 1.7min
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  17.6s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   7.0s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   7.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=  20.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=  35.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  27.4s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time= 1.4min
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=100; total time=   4.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=100; total time=   4.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=  12.1s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=  30.7s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  44.9s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  29.6s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   4.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=  11.8s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=  18.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  50.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  12.2s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=  31.4s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time=  47.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  31.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   4.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  11.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  19.1s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=  46.3s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  11.4s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=800; total time=  31.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=1200; total time=  47.7s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=800; total time=  31.0s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   5.4s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=  15.6s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  22.6s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=1200; total time=  54.0s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=  21.9s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=  34.2s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=   4.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  12.2s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=500; total time=  25.9s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=5, n_estimators=1200; total time=  53.8s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=500; total time=  23.2s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=800; total time=  35.4s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=100; total time=   4.8s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=100; total time=   4.0s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=300; total time=  12.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=500; total time=  23.3s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=1200; total time=  57.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  20.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  47.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time= 2.8min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  13.3s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  30.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  48.2s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time= 2.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=  25.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  49.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   5.7s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=  19.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=  26.3s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  18.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=  49.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  47.6s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   6.1s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  18.5s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=  30.1s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  17.9s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=800; total time=  47.3s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=800; total time=  50.0s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=2000; total time= 2.2min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   6.0s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=  15.6s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  27.9s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=15, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=  18.4s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=  39.9s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=800; total time=  44.9s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=15, n_estimators=100; total time=   5.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=15, n_estimators=300; total time=  16.5s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=15, n_estimators=500; total time=  27.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=15, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=300; total time=  15.3s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=800; total time=  43.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  21.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  22.2s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.0min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  56.2s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  20.5s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  34.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  21.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  56.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  55.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   7.0s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=  21.1s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  34.7s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=  24.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  59.3s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  57.4s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time= 2.8min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=  10.3s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   8.4s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  27.3s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=100, n_estimators=500; total time=  42.3s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=100, n_estimators=1200; total time= 1.8min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  26.2s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time= 1.0min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 2.7min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10, n_estimators=2000; total time= 2.7min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   8.8s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=  24.1s
# ...
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.7s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   9.2s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  16.7s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  44.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  22.5s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=  50.3s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=500; total time=  19.8s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time=  30.1s
# [CV] END max_depth=3, min_samples_leaf=1, min_samples_split=100, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  10.9s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  21.7s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  46.1s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=  11.3s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=800; total time=  30.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  51.3s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=  31.6s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=100, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  11.7s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  18.6s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  45.8s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=  11.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  30.4s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; total time=  46.2s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=800; total time=  31.3s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=100, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=2, n_estimators=2000; total time= 1.3min
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   4.1s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=  12.8s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  20.6s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=1200; total time=  56.9s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=  13.9s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=800; total time=  36.5s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=15, n_estimators=1200; total time=  52.7s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=  34.8s
# [CV] END max_depth=3, min_samples_leaf=10, min_samples_split=100, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=2, n_estimators=2000; total time= 1.5min
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=300; total time=  13.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=500; total time=  23.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=10, n_estimators=1200; total time=  54.4s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=300; total time=  13.6s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=800; total time=  34.1s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=15, n_estimators=1200; total time=  53.9s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=800; total time=  36.5s
# [CV] END max_depth=3, min_samples_leaf=50, min_samples_split=100, n_estimators=2000; total time= 1.6min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  13.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  14.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=  25.8s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  52.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time= 2.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=500; total time=  34.2s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=800; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=100, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  18.8s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  29.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  29.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  50.3s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time= 1.9min
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   5.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=100; total time=   5.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=  17.3s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=  32.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=100, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=  19.2s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  51.2s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=1200; total time= 1.2min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  46.3s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time= 2.1min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time= 2.0min
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=100; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=  18.7s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=500; total time=  29.8s
# [CV] END max_depth=5, min_samples_leaf=5, min_samples_split=100, n_estimators=1200; total time= 1.3min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  18.4s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=800; total time=  50.7s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  47.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=5, n_estimators=2000; total time= 1.9min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=10, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   6.0s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=  18.1s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=  27.8s
# [CV] END max_depth=5, min_samples_leaf=10, min_samples_split=100, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=300; total time=  16.1s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=800; total time=  44.6s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=2, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=800; total time=  42.6s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=5, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=10, n_estimators=2000; total time= 1.8min
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=100; total time=   5.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=300; total time=  15.4s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=500; total time=  25.8s
# [CV] END max_depth=5, min_samples_leaf=50, min_samples_split=100, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  41.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  21.4s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  36.4s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=10, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=100; total time=   6.8s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=300; total time=  20.1s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=500; total time=  34.8s
# [CV] END max_depth=8, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  20.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=  54.7s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=  56.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time= 2.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   7.3s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   7.1s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=300; total time=  20.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=  34.8s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time= 1.4min
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=  35.2s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=800; total time=  55.0s
# [CV] END max_depth=8, min_samples_leaf=2, min_samples_split=100, n_estimators=2000; total time= 2.3min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=  22.4s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  39.1s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  35.2s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  57.9s
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=2000; total time= 2.8min
# [CV] END max_depth=8, min_samples_leaf=5, min_samples_split=15, n_estimators=2000; total time= 3.0min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=  13.9s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=  24.3s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  46.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=2, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=  24.6s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time= 1.0min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10, n_estimators=2000; total time= 2.7min
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=15, n_estimators=2000; total time= 3.0min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=2, n_estimators=300; total time=  28.0s
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=2, n_estimators=500; total time=  35.5s
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=2, n_estimators=1200; total time= 1.5min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=5, n_estimators=300; total time=  24.3s
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=5, n_estimators=800; total time= 1.0min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=5, n_estimators=1200; total time= 1.6min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=10, n_estimators=800; total time= 1.1min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=10, n_estimators=2000; total time= 2.6min
# [CV] END max_depth=8, min_samples_leaf=50, min_samples_split=15, n_estimators=2000; total time= 2.5min
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.7s

# %%
bestF.best_score_
# Out:
# 0.6174593821105153

# %%
bestF.best_params_
# Out:
# {'max_depth': 25,
#  'min_samples_leaf': 2,
#  'min_samples_split': 100,
#  'n_estimators': 800}

# %% [markdown]
# # Testing

# %% [markdown]
# ## Saving the Model

# %%
bestF.best_params_, bestF.best_score_
# Out:
# ({'max_depth': 25,
#   'min_samples_leaf': 2,
#   'min_samples_split': 100,
#   'n_estimators': 800},
#  0.6174593821105153)

# %%
accuracy_score(y_test, bestF.predict(X_test))
# Out:
# 0.6206437661149463

# %%
confusion_matrix(y_test, bestF.predict(X_test))
# Out:
# array([[3677, 2335],
#        [2226, 3785]])

# %%
print(classification_report(y_test, bestF.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62      6012
#            1       0.62      0.63      0.62      6011
#
#     accuracy                           0.62     12023
#    macro avg       0.62      0.62      0.62     12023
# weighted avg       0.62      0.62      0.62     12023

# %% [markdown]
# ### This model has a really poor accuracy score of 0.62.
# ### I think I need to include the 'job_position, tariff_id, education, marital_status.' categorical columns and train the model again.

# %% [markdown]
# ## Saving the Model

# %%
pickle.dump(bestF, open('Random_Forest062.pickle', 'wb'))
